# %% [markdown]
# # How to run IDyOMpy and codeForPaper

# %% [markdown]
# #### Create a new conda environment and activate it
#
# (the current one is saved in SigMA-IDyOMpy/codeForPaper-IDyOMpy-/IDyOM/miniconda3/envs so navigate there first and then activate)

# %%
conda create -n idyompyenv
conda activate idyompyenv

# %% [markdown]
# #### Get the code_for_paper repo from GitHub

# %%
git clone https://github.com/GuiMarion/codeForPaper-IDyOMpy-.git

# %% [markdown]
# #### Navigate inside the "codeForPaper-IDyOMpy" and clone the original IDyOM repo and navigate inside:

# %%
cd codeForPaper-IDyOMpy
git clone https://github.com/GuiMarion/IDyOM.git
cd IDyOM

# %% [markdown]
# #### Make a virtual environment

# %%
python3 -m venv venv
source venv/bin/activate

# %% [markdown]
# #### Install the dependencies:

# %%
pip install -r requirements.txt

# %% [markdown]
# ## Run Bash Scripts for Benchmark plots
#
# #### Copy over the relevant bash script inside of the IDyOM folder. Then make a text file to save the terminal output into so you can check for errors later. (I named mine "bm_IDyOMpy_PPM.txt")
#
# #### From inside IDyOMpy, make the bash script executable (replace bash script name as needed)

# %%
chmod +x run_for_benchmark_IDyOMpy.sh

# %% [markdown]
# #### Make sure your virtual environments are activated, and then run the bash script

# %%
./run_for_benchmark_IDyOMpy.sh 2>&1 | tee bm_IDyOMpy_PPM.txt
./run_for_benchmark_IDyOMpy_ppm.sh 2>&1 | tee bm_IDyOMpy_PPM.log

# %% [markdown]
# run_for_benchmark_IDyOMpy
# - started at 3:31 pm Dec 10th
# - finished at 3:49 pm Dec 10th
#
# run_for_benchmark_IDyOMpy_PPM (run consecutively)
# - started at 3:52 pm Dec 10th
# - early termination
# - results saved in bm_IDyOMpy_PPM.txt
#
# run_for_benchmark_IDyOMpy_Genuine (run after re-cloning a new repo from scratch)
# - started at 5:05 pm Dec 10th
# - early termination at 7:05 pm Dec 10th
# - results saved in benchmark_GE.txt

# %% [markdown]
# ## Use the python versions of the Bash Scripts
#
# To use the python version of the scripts, navigate your terminal to the IDyOM folder, then call this code

# %%
python3 run_for_benchmark_IDyOM.py | tee benchmark.log

python3 run_for_benchmark_IDyOMpy_genuine.py | tee benchmark_genuine.log

python3 run_for_benchmark_IDyOMpy_PPM.py | tee benchmark_ppm.log

# %% [markdown]
# ## If you need to restart
# delete out the models created
# delete out the "out" folder in IDyOM

# %% [markdown]
# ### Notes on running:
#
# If you need to restart, delete the IDyOM folder within the codeForPaper repo, delete the benchmark results folder as well, then restart from cloning in the new IDyOM repo. A folder called .TEMP and out are created during this Bash script.
#
# PPM model bash script checks for an additional 3 models (.._originalPPM) to be deleted if present.
#
# #### Running the actual python files
#
#
# **IDyOM_AE** file runs App.py -t (TRAIN_FOLDER) and -s (TRIAL_FOLDER) what surprisal is calculated on:
# | -t (Train)             | -s (Calc Surprisal)    |
# |------------------------|------------------------|
# | train_shanxi (Chinese) | bach_Pearce            |
# | bach_Pearce (Bach)     | train_shanxi           |
# | mixed2 (Large Western) | stimuli/GregoireMcGill |
#
#
# Then file computes cross entropy of the bach_Pearce folder while also running App.py on these combinations of training / surprisal validation:
# | -t (Train)             | -s (Calc Surprisal)    |
# |------------------------|------------------------|
# | mixed2 (Large Western) | stimuli/giovanni /          |
# | mixed2 (Large Western) | stimuli/Gold/        |
# | bach_Pearce (Bach)  | stimuli/GregoireMcGill |
# | bach_Pearce (Bach)  | stimuli/giovanni /          |
#
#
# Also then calls -e on the bach_Pearson folder, which trains and evaluates over training, but does just -c cross entropy calculation for train_shanxi and mixed2.
#
# These scripts print and save alot of results, which are then copied from the "out" folder into the benchmark_results folder.
#
#
# **IDyOM_PPM** does a nearly similar set of actions, except it adds -o 1 to each line meaning to use the Partial Pattern Matching function from the original Lisp implementation.
#
# It also upfront starts to calc the cross entropy of all 3 datasets, bach_Pearce, train_shanxi, and mixed2 with -o 1 while training the same 4  combination of datasets and validations above.
#
# Once that's all done, it copies the values from out folder into the benchmark results
#
# **IDyOM_GE** has the same exact set up but with -g instead of -o everywhere. This is noted to be 5 times slower than the original file which makes sense based on my latest experiments, but I havent been able to get the job to fully finish.

# %% [markdown]
# ## Looking at the Results

# %% [markdown]
# In the newly created "benchmark_results" folder located above the IDyOM folder, you will see the "likelihoods_cross_eval_k_fold_5_quantization_24_maxOrder_20_viewpoints_pitch_length" results in matplot and in pickle form for each of the datasets trained on.
#
# In matplot, you will unpack multiple variables each corresponds to a song. For each song you have the Information Content (generalization error) as the first dimension, and then the Relative Entropy as the second dimension. They are both vectors over the time dimension. These measures relate to the surprisal we are seeing.
#
# ## Open Questions:
# - How do we group together results for the mean generalization error (IC) values in the chart? is this over time first in the song, then across songs?
# - Why does IDyOM_GE and PPM not finish running but the other one does?
#
# ## Things to try next:
# - Comment out all versions of results we don't need and see if we can just run once on the dataset
# - Read the Bash script thoroughly and convert it to a customizable Python script including printing the terminal results into a text file (or add this to the bash code??)
#
# - confirm that out put matches his output in main analysis (within 0.01 of the value, likely due to randomness)
#
# - find scripts to generate figures in mainanalysis (found eps files, but not the function that goes from matlab to .eps
# )
# - confirm what the unit of time is (midi note onset, or time duration) - confirmed this is note onset, the number of instances is equal to the # of midi notes

# %% [markdown]
# ## Convert .eps files to .pdf for viewing

# %%
gs -dSAFER -dBATCH -dNOPAUSE \
   -sDEVICE=pdfwrite \
   -dEPSCrop=false \
   -sOutputFile=Fig1_GeneralizationErrors.pdf Fig1_GeneralizationErrors.eps

# %%
! python3 codeForPaper-IDyOMpy-/IDyOM/App.py -t codeForPaper-IDyOMpy-/dataset/mixed2 -s codeForPaper-IDyOMpy-/IDyOM/stimuli/eLife -v 'pitch' -o 1
# Out:
# Viewpoints to use: ['pitch']
# Training ...
#
# ________ We are working on 'codeForPaper-IDyOMpy-/dataset/mixed2'
#
# _____ Filling the database ...
#
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-026.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-032.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-152.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-146.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-185.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-184.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-147.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-153.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-033.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-027.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-031.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-025.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-019.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-145.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-151.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-179.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-178.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-150.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-144.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-018.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-024.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-030.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-008.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-034.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-020.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-168.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-140.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-154.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-183.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-182.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-155.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-141.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-169.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-021.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-035.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-009.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-023.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-037.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-157.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-143.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-180.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-181.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor-142.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/bach_Pearce/chor
mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos040.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos068.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos108.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos109.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos069.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos041.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos055.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos082.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos096.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos092.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos086.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos079.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos051.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos045.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos119.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos118.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos044.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos050.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos078.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos087.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos093.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos085.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos091.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos046.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos052.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos053.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos047.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos090.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos084.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos020.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos034.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos008.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos009.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos035.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos021.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos037.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos023.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos022.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos036.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos032.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos026.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos027.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos033.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos019.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos025.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos031.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos030.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos024.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/jugoslav/jugos018.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr032.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr026.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr027.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr033.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr019.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr025.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr031.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr030.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr024.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr018.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr020.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr034.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr008.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr009.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr035.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr021.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr037.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr023.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr022.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr036.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr092.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr086.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr079.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr051.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr045.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr044.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr050.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr078.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr087.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr093.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr085.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr091.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr046.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr052.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr053.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr047.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr090.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr084.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr080.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr094.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr043.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr057.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr056.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr042.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr095.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr081.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr097.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr083.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr054.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr040.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr068.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr069.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr041.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr055.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr082.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr096.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr058.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr070.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr064.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr104.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr065.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr071.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr059.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr098.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr067.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr073.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr072.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr066.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr099.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr089.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr062.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr076.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr102.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr103.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr077.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr063.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr088.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr075.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr061.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr049.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr101.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr100.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr048.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr060.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr074.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr013.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr007.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr006.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr012.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr038.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr004.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr010.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr011.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr005.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr039.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr001.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr015.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr029.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr028.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr014.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr016.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr002.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr003.mid
#  - codeForPaper-IDyOMpy-/dataset/mixed2/oesterrh/oestr017.mid
#
# We passed a total of  957 files.
# 0 of them have been skiped.
#
# _____ Computing multiple viewpoints representation
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# _____ Augmenting database ...
#
# Data processing done.
# Traceback (most recent call last):
#   File "/Users/arianapereira/Documents/Masters/Projects/SigMA/musical-surprisal/IDyOM/codeForPaper-IDyOMpy-/IDyOM/App.py", line 657, in <module>
#     Train(options.train_folder, quantization=options.quantization, maxOrder=options.max_order, \
#   File "/Users/arianapereira/Documents/Masters/Projects/SigMA/musical-surprisal/IDyOM/codeForPaper-IDyOMpy-/IDyOM/App.py", line 211, in Train
#     L.save("models/"+ str(folder[folder.rfind("/")+1:]) + "_quantization_"+str(quantization)+"_maxOrder_"+str(maxOrder)+"_viewpoints_"+vstr(viewPoints)+ppm_name+ ".model")
#   File "/Users/arianapereira/Documents/Masters/Projects/SigMA/musical-surprisal/IDyOM/codeForPaper-IDyOMpy-/IDyOM/idyom/idyom.py", line 713, in save
#     f = open(file, 'wb')
#         ^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'models/mixed2_quantization_24_maxOrder_20_viewpoints_pitch_originalPPM.model'

# %%
! python3 codeForPaper-IDyOMpy-/IDyOM/App.py -t codeForPaper-IDyOMpy-/dataset/mixed2 -s codeForPaper-IDyOMpy-/IDyOM/stimuli/eLife -v 'length' -o 1
# Out:
# /Users/arianapereira/Documents/Masters/Projects/SigMA/musical-surprisal/IDyOM
