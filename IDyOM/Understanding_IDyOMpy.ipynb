# %% [markdown]
# # Understanding IDyOMpy - by Guilhem Marion
# Source Repo available: https://github.com/GuiMarion/IDyOMpy/tree/master

# %%
# from codeForPaper-IDyOMpy-.IDyOM.idyom import idyom, data
# from codeForPaper-IDyOMpy-.IDyOM.App import Train, SurpriseOverFolder, cross_validation
import mido
import collections
import numpy as np

# %%
train_path = "trainingFolder/"
eval_path = "testFolder/"

# %% [markdown]
# # General Notes
#
# ### 1. Train Model - this function trains a model with midi files contained in the passed folder and saves it in model folder. Parameters include:
# - maxOrder: fed into idyom.idyom function as the limit of how long an n-gram (a chunk of melody) can be
# - time_representation: used in train_by_piece.. ???
# - zero_padding: defaults to True ..???
# - long_term_only: defaults to false meaning we use both forms of memory and pre-compute Entropy
# - short_term_only: defaults to false meaning we use both forms of memory and pre-compute Entropy
# - viewPoints: (options: ['pitch', 'length', 'interval', 'velocity']) what you train the model to use as features which inform the markov chain prediction
# #### a. Class idyom.idyom() - called within App.Train() and represents the entire model. Parameters include:
# - maxOrder: maximal order of the model
# - viewPoints: viewPoint to use
# - stm: defaults to True meaning we will use the short term model
# - evolution: defaults to False
# ##### .train() - function within idyom.idyom() which trains a new LTM model based on data.getData(viewPoint) and preComputesEntropies if we are using both LTM and STM
# ##### .mergeProbas() - function to merge probabilities from different models by doing a weighted average
# - probas: the probabilities you will merge
# - weights: weight applied to each model's probabilities when merging into 1 average; calc'ed from normalized entropy
# #### b. Class data.data() - called within idyom.idyom() constructor to train the LTM model. Parameters include:
# - quantization: defaults to 24 which is the smallest measure of rhythm, 16 meaning 1/16th of a beat
# - viewpoints: described above, if none provided defaults to all
# - deleteDuplicates: if true, allows the program to delete duplicate files during training
# ##### .getViewpointRepresentation() - function which creates a dictionary of viewpoints where each viewpoint has a sub-array which stores the data related to that viewpoint
# ##### .dataToViewpoint() - function that stores a numerical representation for each viewpoint inputted based on the Midi score data into one dictionary
# - "length" = score.duration()[:-1]
# - "pitch" = score.pitch
# - "interval" = list of the distance between pitches in the sequence of score.pitch
# - "velocity" = score.velocity
# #### c. Class Score() - a class used to convert midi data into numpy arrays

# %% [markdown]
# # Midi File Processing

# %%
class Note(object):
    """A simple Note object.
    Parameters
    ----------
    velocity : int
        Note velocity.
    pitch : int
        Note pitch, as a MIDI note number.
    start : float
        Note on time, absolute, in ticks.
    end : float
        Note off time, absolute, in ticks.
    """

    def __init__(self, velocity, pitch, start, end):
        self.velocity = velocity
        self.pitch = pitch
        self.start = start
        self.end = end

    def get_duration(self):
        """Get the duration of the note in ticks."""
        return self.end - self.start

    def __repr__(self):
        return 'Note(start={:d}, end={:d}, pitch={}, velocity={})'.format(
            self.start, self.end, self.pitch, self.velocity)

# %%
def getNotesFromMidi(midiFile):
	"""
	Compute a list of Note objects from a midi file.
	----------
	midiFile : str
		Filepath of the midi file.

	Returns
	-------
	notes : list of Note.
		List of Note objects.
	"""

	mido_obj = mido.MidiFile(midiFile)

	# Delta to cumulative
	for track in mido_obj.tracks:
		tick = int(0)
		for event in track:
			event.time += tick
			tick = event.time
	NOTES = []
	# We extract the notes from the events
	for track_idx, track in enumerate(mido_obj.tracks):
		# Keep track of last note on location:
		last_note_on = collections.defaultdict(list)

		notes = []
		for event in track:
			if event.type == 'note_on' and event.velocity > 0:
				# Store this as the last note-on location
				note_on_index = (event.channel, event.note)
				last_note_on[note_on_index].append((
					event.time, event.velocity))
			# Note offs can also be note on events with 0 velocity
			elif event.type == 'note_off' or (event.type == 'note_on' and
											  event.velocity == 0):
				# Check that a note-on exists (ignore spurious note-offs)
				key = (event.channel, event.note)
				if key in last_note_on:
					# Get the start/stop times and velocity of every note
					# which was turned on with this instrument/drum/pitch.
					# One note-off may close multiple note-on events from
					# previous ticks. In case there's a note-off and then
					# note-on at the same tick we keep the open note from
					# this tick.
					end_tick = event.time
					open_notes = last_note_on[key]

					notes_to_close = [
						(start_tick, velocity)
						for start_tick, velocity in open_notes
						if start_tick != end_tick]
					notes_to_keep = [
						(start_tick, velocity)
						for start_tick, velocity in open_notes
						if start_tick == end_tick]

					for start_tick, velocity in notes_to_close:
						start_time = start_tick
						end_time = end_tick
						# Create the note event
						note = Note(velocity, event.note, start_time,
									end_time)
			
						notes.append(note)

					if len(notes_to_close) > 0 and len(notes_to_keep) > 0:
						# Note-on on the same tick but we already closed
						# some previous notes -> it will continue, keep it.
						last_note_on[key] = notes_to_keep
					else:
						# Remove the last note on for this instrument
						del last_note_on[key]

			elif event.type == 'end_of_track':
				# This is not more reliable than looking at the encoded duration.
				pass
		NOTES.append(notes)

	isPoly = False
	for N in NOTES:
		if len(N) > 0:
			if isPoly:
				raise RuntimeError("This file is polyphonic, I cannot handle this: "+str(midiFile))
			notes = N
			isPoly = True

	if not isPoly:
		raise RuntimeError("This file is empty, I cannnot handle this ... " + str(midiFile))

	return notes, mido_obj.ticks_per_beat

# %%
midiFile = "codeForPaper-IDyOMpy-/dataset/bach_Pearce/chor-183.mid"

notes, ticks_per_beat = getNotesFromMidi(midiFile)

print("Notes:", len(notes))
for note in notes:
    print("\n", note) 

print("Ticks Per Beat:", ticks_per_beat)
# Out:
# Notes: 47
#
#  Note(start=72, end=96, pitch=64, velocity=100)
#
#  Note(start=96, end=120, pitch=71, velocity=100)
#
#  Note(start=120, end=144, pitch=68, velocity=100)
#
#  Note(start=144, end=168, pitch=64, velocity=100)
#
#  Note(start=168, end=192, pitch=71, velocity=100)
#
#  Note(start=192, end=216, pitch=73, velocity=100)
#
#  Note(start=216, end=240, pitch=73, velocity=100)
#
#  Note(start=240, end=264, pitch=71, velocity=100)
#
#  Note(start=264, end=288, pitch=71, velocity=100)
#
#  Note(start=288, end=312, pitch=73, velocity=100)
#
#  Note(start=312, end=336, pitch=75, velocity=100)
#
#  Note(start=336, end=360, pitch=76, velocity=100)
#
#  Note(start=360, end=384, pitch=75, velocity=100)
#
#  Note(start=384, end=408, pitch=73, velocity=100)
#
#  Note(start=408, end=432, pitch=73, velocity=100)
#
#  Note(start=432, end=456, pitch=71, velocity=100)
#
#  Note(start=456, end=480, pitch=68, velocity=100)
#
#  Note(start=480, end=504, pitch=73, velocity=100)
#
#  Note(start=504, end=528, pitch=71, velocity=100)
#
#  Note(start=528, end=552, pitch=69, velocity=100)
#
#  Note(start=552, end=576, pitch=68, velocity=100)
#
#  Note(start=576, end=624, pitch=66, velocity=100)
#
#  Note(start=624, end=648, pitch=64, velocity=100)
#
#  Note(start=672, end=720, pitch=71, velocity=100)
#
#  Note(start=720, end=768, pitch=68, velocity=100)
#
#  Note(start=768, end=816, pitch=71, velocity=100)
#
#  Note(start=816, end=864, pitch=68, velocity=100)
#
#  Note(start=864, end=888, pitch=69, velocity=100)
#
#  Note(start=888, end=912, pitch=68, velocity=100)
#
#  Note(start=912, end=936, pitch=66, velocity=100)
#
#  Note(start=936, end=960, pitch=68, velocity=100)
#
#  Note(start=960, end=984, pitch=69, velocity=100)
#
#  Note(start=984, end=1008, pitch=68, velocity=100)
#
#  Note(start=1008, end=1032, pitch=66, velocity=100)
#
#  Note(start=1032, end=1056, pitch=68, velocity=100)
#
#  Note(start=1056, end=1080, pitch=69, velocity=100)
#
#  Note(start=1080, end=1104, pitch=68, velocity=100)
#
#  Note(start=1104, end=1152, pitch=66, velocity=100)
#
#  Note(start=1152, end=1200, pitch=64, velocity=100)
#
#  Note(start=1200, end=1224, pitch=76, velocity=100)
#
#  Note(start=1224, end=1248, pitch=75, velocity=100)
#
#  Note(start=1248, end=1272, pitch=73, velocity=100)
#
#  Note(start=1272, end=1296, pitch=71, velocity=100)
#
#  Note(start=1296, end=1320, pitch=69, velocity=100)
#
#  Note(start=1320, end=1344, pitch=68, velocity=100)
#
#  Note(start=1344, end=1392, pitch=66, velocity=100)
#
#  Note(start=1392, end=1416, pitch=64, velocity=100)
# Ticks Per Beat: 24

# %% [markdown]
# ### Questions:
# - What is "ticks per beat" does this mean BPM since default tempo is 120?

# %% [markdown]
# # Replicating EEG Study

# %%
train_path = "trainingFolder/"
eval_path = "testFolder/"
quantization = 24
maxOrder = 20
viewPoints = ["pitch", "length"]

# %%
# 1. Train the model
Train(
    folder=train_path,
    quantization=quantization,
    maxOrder=maxOrder,
    viewPoints=viewPoints,
)
# Out:
# ________ We are working on 'trainingFolder'
#
# _____ Filling the database ...
#
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse66.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse72.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse73.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse67.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse59.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse71.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse65.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse64.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse70.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse58.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse74.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse60.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse48.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse49.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse61.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse75.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse63.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse77.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse88.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse89.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse76.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse62.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse39.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse05.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse11.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse10.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse04.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse38.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse12.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse06.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse07.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse13.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse17.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse03.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse02.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse16.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse14.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse28.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse29.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse15.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse01.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse18.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse24.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse30.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse31.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse25.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse19.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse33.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse27.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse26.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse32.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse36.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse22.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse23.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse37.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse21.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse35.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse09.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse08.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse34.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse20.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse47.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse53.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse84.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse90.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse91.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse85.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse52.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse46.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse78.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse50.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse44.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse93.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse87.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse86.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse92.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse45.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse51.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse79.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse55.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse41.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse69.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse82.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse83.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse68.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse40.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse54.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse42.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse56.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse81.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse80.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse57.mid
#  - trainingFolder/largeWestern_wt_bach/schweiz/suisse43.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova105.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova111.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova139.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova044b.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova071.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova065.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova059.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova121a.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova058.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova064.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova070.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova138.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova110.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova104.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova112.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova106.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova099.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova066.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova072.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova044a.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova121b.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova073.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova067.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova098.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova107.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova113.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova117.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova103.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova088.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova063.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova077.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova076.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova062.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova089.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova102.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova116.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova128.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova100.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova114.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova048.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova074.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova060.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova061.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova075.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova049.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova115.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova101.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova129.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova012.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova006.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova007.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova013.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova005.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova011.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova039.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova038.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova010.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova004.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova148.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova028.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova014.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova015.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova001.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova029.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova149.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova017.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova003.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova002.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova016.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova147.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova033.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova027.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova026.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova032.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova146.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova150.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova144.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova024.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova030.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova018.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova019.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova031.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova025.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova145.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova141.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova009.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova021.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova035.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova034.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova020.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova008.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova140.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova142.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova036.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova022.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova023.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova037.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova143.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova124.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova130.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova118.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova093.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova087.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova050.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova078.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova079.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova045.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova051.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova086.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova092.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova119.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova131.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova125.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova133.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova127.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova084.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova090.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova047.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova053.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova052.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova046.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova091.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova085.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova126.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova132.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova136.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova122.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova081.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova095.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova042.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova056.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova057.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova043.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova094.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova080.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova123.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova137.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova109.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova135.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova096.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova082.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova069.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova055.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova041.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova040.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova054.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova068.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova083.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova097.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova134.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova120.mid
#  - trainingFolder/largeWestern_wt_bach/nova/nova108.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr075.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr061.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr049.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr101.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr115.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr129.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr128.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr114.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr100.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr048.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr060.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr074.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr089.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr062.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr076.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr116.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr102.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr103.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr117.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr077.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr063.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr088.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr098.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr067.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr073.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr113.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr107.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr106.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr112.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr072.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr066.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr099.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr058.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr070.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr064.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr138.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr104.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr110.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr111.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr105.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr139.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr065.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr071.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr059.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr016.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr002.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr200.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr189.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr162.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr176.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr177.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr163.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr188.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr201.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr003.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr017.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr001.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr015.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr029.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr203.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr175.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr161.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr149.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr148.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr160.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr174.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr202.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr028.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr014.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr038.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr004.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr010.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr206.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr212.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr158.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr170.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr164.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr165.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr171.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr159.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr213.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr207.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr011.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr005.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr039.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr013.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr007.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr211.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr205.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr198.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr167.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr173.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr172.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr166.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr199.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr204.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr210.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr006.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr012.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr037.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr023.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr209.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr180.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr194.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr143.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr157.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr156.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr142.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr195.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr181.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr208.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr022.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr036.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr020.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr034.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr008.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr197.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr183.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr154.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr140.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr168.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr169.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr141.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr155.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr182.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr196.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr009.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr035.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr021.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr019.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr025.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr031.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr192.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr186.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr179.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr151.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr145.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr144.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr150.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr178.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr187.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr193.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr030.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr024.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr018.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr032.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr026.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr185.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr191.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr146.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr152.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr153.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr147.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr190.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr184.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr027.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr033.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr097.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr083.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr054.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr040.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr068.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr120.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr134.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr108.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr109.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr135.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr121.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr069.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr041.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr055.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr082.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr096.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr080.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr094.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr043.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr057.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr137.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr123.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr122.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr136.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr056.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr042.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr095.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr081.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr085.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr091.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr046.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr052.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr132.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr126.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr127.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr133.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr053.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr047.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr090.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr084.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr092.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr086.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr079.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr051.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr045.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr119.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr125.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr131.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr130.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr124.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr118.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr044.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr050.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr078.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr087.mid
#  - trainingFolder/largeWestern_wt_bach/kinder/kindr093.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass37.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass23.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass22.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass36.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass08.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass20.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass34.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass35.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass21.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass09.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass25.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass31.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass19.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass18.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass30.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass24.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass32.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass26.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass27.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass33.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass83.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass68.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass54.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass40.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass41.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass55.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass69.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass82.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass80.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass43.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass57.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass56.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass42.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass81.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass85.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass91.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass46.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass52.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass53.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass47.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass90.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass84.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass86.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass51.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass45.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass79.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass78.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass44.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass50.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass87.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass49.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass75.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass61.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass60.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass74.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass48.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass89.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass62.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass76.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass77.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass63.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass88.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass67.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass73.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass72.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass66.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass70.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass64.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass58.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass59.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass65.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass71.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass16.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass02.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass03.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass17.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass29.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass01.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass15.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass14.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass28.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass04.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass10.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass38.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass39.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass11.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass05.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass13.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass07.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass06.mid
#  - trainingFolder/largeWestern_wt_bach/elsass/elsass12.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos001.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos015.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos029.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos028.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos014.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos016.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos002.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos003.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos017.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos013.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos007.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos006.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos012.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos038.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos004.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos010.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos011.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos005.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos039.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos089.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos062.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos076.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos116.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos102.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos103.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos117.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos077.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos063.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos088.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos075.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos061.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos049.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos101.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos115.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos114.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos100.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos048.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos060.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos074.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos058.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos070.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos064.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos104.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos110.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos111.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos105.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos065.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos071.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos059.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos098.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos067.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos073.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos113.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos107.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos106.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos112.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos072.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos066.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos099.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos080.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos094.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos043.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos057.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos056.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos042.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos095.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos081.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos097.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos083.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos054.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos040.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos068.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos108.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos109.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos069.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos041.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos055.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos082.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos096.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos092.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos086.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos079.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos051.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos045.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos119.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos118.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos044.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos050.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos078.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos087.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos093.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos085.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos091.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos046.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos052.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos053.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos047.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos090.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos084.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos020.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos034.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos008.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos009.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos035.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos021.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos037.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos023.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos022.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos036.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos032.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos026.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos027.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos033.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos019.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos025.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos031.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos030.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos024.mid
#  - trainingFolder/largeWestern_wt_bach/jugoslav/jugos018.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr032.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr026.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr027.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr033.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr019.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr025.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr031.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr030.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr024.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr018.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr020.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr034.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr008.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr009.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr035.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr021.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr037.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr023.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr022.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr036.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr092.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr086.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr079.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr051.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr045.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr044.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr050.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr078.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr087.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr093.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr085.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr091.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr046.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr052.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr053.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr047.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr090.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr084.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr080.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr094.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr043.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr057.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr056.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr042.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr095.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr081.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr097.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr083.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr054.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr040.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr068.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr069.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr041.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr055.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr082.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr096.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr058.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr070.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr064.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr104.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr065.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr071.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr059.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr098.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr067.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr073.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr072.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr066.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr099.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr089.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr062.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr076.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr102.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr103.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr077.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr063.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr088.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr075.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr061.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr049.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr101.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr100.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr048.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr060.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr074.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr013.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr007.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr006.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr012.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr038.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr004.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr010.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr011.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr005.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr039.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr001.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr015.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr029.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr028.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr014.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr016.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr002.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr003.mid
#  - trainingFolder/largeWestern_wt_bach/oesterrh/oestr017.mid
#
# We passed a total of  772 files.
# 0 of them have been skiped.
#
# _____ Computing multiple viewpoints representation
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# We found a duplicate, we ignore it. We encourage you to check your dataset with App.py -c 1
# _____ Augmenting database ...
#
# Data processing done.

# %%
# 2. Load model
train_name = train_path.rstrip("/").split("/")[-1]

model_path = f"models/{train_name}_quantization_{quantization}_maxOrder_{maxOrder}_viewpoints_{viewPoints[0]}_{viewPoints[1]}.model"
print(model_path)

model = idyom.idyom()
model.load(model_path)
# Out:
# models/trainingFolder_quantization_24_maxOrder_20_viewpoints_pitch_length.model

# %%
# 3. Surprise for a single file
IC = model.getSurprisefromFile(
    midiFile,
    genuine_entropies=False,
    short_term_only=False,
    long_term_only=False
)

print(IC)

import matplotlib.pyplot as plt

plt.plot(IC)
# Out:
# (array([ 5.19031694,  5.15381499,  3.16967433, ...,  6.11365279,
#         6.33770388, 52.        ], shape=(1022,)), array([4.59102074, 4.47621174, 3.74961209, ..., 3.79302916, 3.02991114,
#        2.25228362], shape=(1022,)))
# [<matplotlib.lines.Line2D at 0x331170e60>,
#  <matplotlib.lines.Line2D at 0x117b0b860>,
#  <matplotlib.lines.Line2D at 0x117b092e0>,
#  <matplotlib.lines.Line2D at 0x117920ad0>,
#  <matplotlib.lines.Line2D at 0x117921310>,
#  <matplotlib.lines.Line2D at 0x117922600>,
#  <matplotlib.lines.Line2D at 0x117922840>,
#  <matplotlib.lines.Line2D at 0x117921c10>,
#  <matplotlib.lines.Line2D at 0x117b09f70>,
#  <matplotlib.lines.Line2D at 0x117921460>,
#  <matplotlib.lines.Line2D at 0x117920770>,
#  <matplotlib.lines.Line2D at 0x117920f80>,
#  <matplotlib.lines.Line2D at 0x117922a20>,
#  <matplotlib.lines.Line2D at 0x117922810>,
#  <matplotlib.lines.Line2D at 0x117921040>,
#  <matplotlib.lines.Line2D at 0x117922cf0>,
#  <matplotlib.lines.Line2D at 0x117920fe0>,
#  <matplotlib.lines.Line2D at 0x117922240>,
#  <matplotlib.lines.Line2D at 0x1179230e0>,
#  <matplotlib.lines.Line2D at 0x117920140>,
#  <matplotlib.lines.Line2D at 0x117922ae0>,
#  <matplotlib.lines.Line2D at 0x1179228a0>,
#  <matplotlib.lines.Line2D at 0x117922540>,
#  <matplotlib.lines.Line2D at 0x117923590>,
#  <matplotlib.lines.Line2D at 0x117923ef0>,
#  <matplotlib.lines.Line2D at 0x117920800>,
#  <matplotlib.lines.Line2D at 0x117920c50>,
#  <matplotlib.lines.Line2D at 0x117921940>,
#  <matplotlib.lines.Line2D at 0x117920c80>,
#  <matplotlib.lines.Line2D at 0x117922030>,
#  <matplotlib.lines.Line2D at 0x1179220f0>,
#  <matplotlib.lines.Line2D at 0x1179201a0>,
#  <matplotlib.lines.Line2D at 0x117ad0fb0>,
#  <matplotlib.lines.Line2D at 0x117ad1e80>,
#  <matplotlib.lines.Line2D at 0x117ad1cd0>,
#  <matplotlib.lines.Line2D at 0x117ad2390>,
#  <matplotlib.lines.Line2D at 0x117ad2180>,
#  <matplotlib.lines.Line2D at 0x117ad0ef0>,
#  <matplotlib.lines.Line2D at 0x117ad2c30>,
#  <matplotlib.lines.Line2D at 0x117ad3170>,
#  <matplotlib.lines.Line2D at 0x117ad3f80>,
#  <matplotlib.lines.Line2D at 0x117ad38c0>,
#  <matplotlib.lines.Line2D at 0x117ad1670>,
#  <matplotlib.lines.Line2D at 0x117ad2810>,
#  <matplotlib.lines.Line2D at 0x117ad3b90>,
#  <matplotlib.lines.Line2D at 0x117ad08f0>,
#  <matplotlib.lines.Line2D at 0x117ad05f0>,
#  <matplotlib.lines.Line2D at 0x117ad32f0>,
#  <matplotlib.lines.Line2D at 0x332b66ae0>,
#  <matplotlib.lines.Line2D at 0x117ad0980>,
#  <matplotlib.lines.Line2D at 0x117ad27b0>,
#  <matplotlib.lines.Line2D at 0x117ad2cc0>,
#  <matplotlib.lines.Line2D at 0x117ad3ef0>,
#  <matplotlib.lines.Line2D at 0x117ad09e0>,
#  <matplotlib.lines.Line2D at 0x117ad2f00>,
#  <matplotlib.lines.Line2D at 0x117ad2ab0>,
#  <matplotlib.lines.Line2D at 0x117ad1490>,
#  <matplotlib.lines.Line2D at 0x117ad2f60>,
#  <matplotlib.lines.Line2D at 0x117ad3560>,
#  <matplotlib.lines.Line2D at 0x117ad3380>,
#  <matplotlib.lines.Line2D at 0x117ad1520>,
#  <matplotlib.lines.Line2D at 0x117920b60>,
#  <matplotlib.lines.Line2D at 0x117ad2330>,
#  <matplotlib.lines.Line2D at 0x117ad14f0>,
#  <matplotlib.lines.Line2D at 0x117ad2d50>,
#  <matplotlib.lines.Line2D at 0x117ad37a0>,
#  <matplotlib.lines.Line2D at 0x117ad3b00>,
#  <matplotlib.lines.Line2D at 0x117ad1f40>,
#  <matplotlib.lines.Line2D at 0x117ad1ac0>,
#  <matplotlib.lines.Line2D at 0x117ad29c0>,
#  <matplotlib.lines.Line2D at 0x117ad2ae0>,
#  <matplotlib.lines.Line2D at 0x117ad3860>,
#  <matplotlib.lines.Line2D at 0x117ad1a90>,
#  <matplotlib.lines.Line2D at 0x117ad0ce0>,
#  <matplotlib.lines.Line2D at 0x117ad38f0>,
#  <matplotlib.lines.Line2D at 0x117ad0e60>,
#  <matplotlib.lines.Line2D at 0x117ad1b20>,
#  <matplotlib.lines.Line2D at 0x116ce7f80>,
#  <matplotlib.lines.Line2D at 0x116ce53d0>,
#  <matplotlib.lines.Line2D at 0x116ce4320>,
#  <matplotlib.lines.Line2D at 0x116ce4980>,
#  <matplotlib.lines.Line2D at 0x116ce4920>,
#  <matplotlib.lines.Line2D at 0x120c072c0>,
#  <matplotlib.lines.Line2D at 0x117b09370>,
#  <matplotlib.lines.Line2D at 0x120c06ea0>,
#  <matplotlib.lines.Line2D at 0x117920260>,
#  <matplotlib.lines.Line2D at 0x120c04830>,
#  <matplotlib.lines.Line2D at 0x120c044d0>,
#  <matplotlib.lines.Line2D at 0x120c074a0>,
#  <matplotlib.lines.Line2D at 0x120c055e0>,
#  <matplotlib.lines.Line2D at 0x120c040e0>,
#  <matplotlib.lines.Line2D at 0x120c07b30>,
#  <matplotlib.lines.Line2D at 0x120c07410>,
#  <matplotlib.lines.Line2D at 0x120c07650>,
#  <matplotlib.lines.Line2D at 0x120c4db80>,
#  <matplotlib.lines.Line2D at 0x120c4df10>,
#  <matplotlib.lines.Line2D at 0x120c4ec00>,
#  <matplotlib.lines.Line2D at 0x120c4e720>,
#  <matplotlib.lines.Line2D at 0x120c4e180>,
#  <matplotlib.lines.Line2D at 0x120c4ef60>,
#  <matplotlib.lines.Line2D at 0x120c4eb40>,
#  <matplotlib.lines.Line2D at 0x116cb9fd0>,
#  <matplotlib.lines.Line2D at 0x116cb9760>,
#  <matplotlib.lines.Line2D at 0x116cb8860>,
#  <matplotlib.lines.Line2D at 0x120c4b230>,
#  <matplotlib.lines.Line2D at 0x120c48c20>,
#  <matplotlib.lines.Line2D at 0x1169f44a0>,
#  <matplotlib.lines.Line2D at 0x120c49fd0>,
#  <matplotlib.lines.Line2D at 0x120c48b30>,
#  <matplotlib.lines.Line2D at 0x120c4b0e0>,
#  <matplotlib.lines.Line2D at 0x120c4a8a0>,
#  <matplotlib.lines.Line2D at 0x120c48500>,
#  <matplotlib.lines.Line2D at 0x120c48d40>,
#  <matplotlib.lines.Line2D at 0x120c4a180>,
#  <matplotlib.lines.Line2D at 0x120c485c0>,
#  <matplotlib.lines.Line2D at 0x120c48d70>,
#  <matplotlib.lines.Line2D at 0x120c49cd0>,
#  <matplotlib.lines.Line2D at 0x120c495b0>,
#  <matplotlib.lines.Line2D at 0x120c4aea0>,
#  <matplotlib.lines.Line2D at 0x120c49670>,
#  <matplotlib.lines.Line2D at 0x120c49dc0>,
#  <matplotlib.lines.Line2D at 0x120c4b350>,
#  <matplotlib.lines.Line2D at 0x120c48620>,
#  <matplotlib.lines.Line2D at 0x120c48dd0>,
#  <matplotlib.lines.Line2D at 0x120c4ab70>,
#  <matplotlib.lines.Line2D at 0x120c48890>,
#  <matplotlib.lines.Line2D at 0x120c4b830>,
#  <matplotlib.lines.Line2D at 0x120c48530>,
#  <matplotlib.lines.Line2D at 0x120c4b800>,
#  <matplotlib.lines.Line2D at 0x120c49eb0>,
#  <matplotlib.lines.Line2D at 0x120c4bb30>,
#  <matplotlib.lines.Line2D at 0x120c49280>,
#  <matplotlib.lines.Line2D at 0x120c4a2d0>,
#  <matplotlib.lines.Line2D at 0x120c48380>,
#  <matplotlib.lines.Line2D at 0x120c4ba70>,
#  <matplotlib.lines.Line2D at 0x120c4a3c0>,
#  <matplotlib.lines.Line2D at 0x120c4b2f0>,
#  <matplotlib.lines.Line2D at 0x120c4ac60>,
#  <matplotlib.lines.Line2D at 0x120c495e0>,
#  <matplotlib.lines.Line2D at 0x120c4b920>,
#  <matplotlib.lines.Line2D at 0x120c49be0>,
#  <matplotlib.lines.Line2D at 0x120c490d0>,
#  <matplotlib.lines.Line2D at 0x120c49730>,
#  <matplotlib.lines.Line2D at 0x120c48830>,
#  <matplotlib.lines.Line2D at 0x120c49f10>,
#  <matplotlib.lines.Line2D at 0x120c49f40>,
#  <matplotlib.lines.Line2D at 0x120c4a810>,
#  <matplotlib.lines.Line2D at 0x120c4b380>,
#  <matplotlib.lines.Line2D at 0x120c48b00>,
#  <matplotlib.lines.Line2D at 0x120c49e80>,
#  <matplotlib.lines.Line2D at 0x120c4acc0>,
#  <matplotlib.lines.Line2D at 0x120c4be60>,
#  <matplotlib.lines.Line2D at 0x120c49460>,
#  <matplotlib.lines.Line2D at 0x11706b320>,
#  <matplotlib.lines.Line2D at 0x11706b2f0>,
#  <matplotlib.lines.Line2D at 0x11719d220>,
#  <matplotlib.lines.Line2D at 0x11719e2a0>,
#  <matplotlib.lines.Line2D at 0x11719eed0>,
#  <matplotlib.lines.Line2D at 0x11719e3c0>,
#  <matplotlib.lines.Line2D at 0x11719f680>,
#  <matplotlib.lines.Line2D at 0x11719ea50>,
#  <matplotlib.lines.Line2D at 0x11719fa10>,
#  <matplotlib.lines.Line2D at 0x11719daf0>,
#  <matplotlib.lines.Line2D at 0x11719ef00>,
#  <matplotlib.lines.Line2D at 0x11719d010>,
#  <matplotlib.lines.Line2D at 0x11719f620>,
#  <matplotlib.lines.Line2D at 0x11719d130>,
#  <matplotlib.lines.Line2D at 0x11719e6c0>,
#  <matplotlib.lines.Line2D at 0x11719df40>,
#  <matplotlib.lines.Line2D at 0x11719e690>,
#  <matplotlib.lines.Line2D at 0x11719f6e0>,
#  <matplotlib.lines.Line2D at 0x11719ede0>,
#  <matplotlib.lines.Line2D at 0x11719ef90>,
#  <matplotlib.lines.Line2D at 0x11719f830>,
#  <matplotlib.lines.Line2D at 0x11719ccb0>,
#  <matplotlib.lines.Line2D at 0x11719da30>,
#  <matplotlib.lines.Line2D at 0x11719eea0>,
#  <matplotlib.lines.Line2D at 0x11719dd60>,
#  <matplotlib.lines.Line2D at 0x11719e930>,
#  <matplotlib.lines.Line2D at 0x11719ce60>,
#  <matplotlib.lines.Line2D at 0x11719faa0>,
#  <matplotlib.lines.Line2D at 0x11719f650>,
#  <matplotlib.lines.Line2D at 0x11719cb60>,
#  <matplotlib.lines.Line2D at 0x11719d0d0>,
#  <matplotlib.lines.Line2D at 0x11719f4d0>,
#  <matplotlib.lines.Line2D at 0x11719ee10>,
#  <matplotlib.lines.Line2D at 0x11719d250>,
#  <matplotlib.lines.Line2D at 0x11719f110>,
#  <matplotlib.lines.Line2D at 0x331173860>,
#  <matplotlib.lines.Line2D at 0x11719d2b0>,
#  <matplotlib.lines.Line2D at 0x1171c40e0>,
#  <matplotlib.lines.Line2D at 0x1171c4a40>,
#  <matplotlib.lines.Line2D at 0x1171c41a0>,
#  <matplotlib.lines.Line2D at 0x1171c5f40>,
#  <matplotlib.lines.Line2D at 0x1171c5460>,
#  <matplotlib.lines.Line2D at 0x117b082f0>,
#  <matplotlib.lines.Line2D at 0x1171c67e0>,
#  <matplotlib.lines.Line2D at 0x1171c5100>,
#  <matplotlib.lines.Line2D at 0x1171c4860>,
#  <matplotlib.lines.Line2D at 0x1171c5790>,
#  <matplotlib.lines.Line2D at 0x1171c5e20>,
#  <matplotlib.lines.Line2D at 0x1171c6ba0>,
#  <matplotlib.lines.Line2D at 0x1171c47a0>,
#  <matplotlib.lines.Line2D at 0x1171c74a0>,
#  <matplotlib.lines.Line2D at 0x1171c44a0>,
#  <matplotlib.lines.Line2D at 0x1171c5250>,
#  <matplotlib.lines.Line2D at 0x1171c4a70>,
#  <matplotlib.lines.Line2D at 0x1171c47d0>,
#  <matplotlib.lines.Line2D at 0x1171c42f0>,
#  <matplotlib.lines.Line2D at 0x1171c5280>,
#  <matplotlib.lines.Line2D at 0x1171c4410>,
#  <matplotlib.lines.Line2D at 0x1171c5fa0>,
#  <matplotlib.lines.Line2D at 0x1171c7650>,
#  <matplotlib.lines.Line2D at 0x1171c6390>,
#  <matplotlib.lines.Line2D at 0x1171c4620>,
#  <matplotlib.lines.Line2D at 0x1171c63f0>,
#  <matplotlib.lines.Line2D at 0x1171c43b0>,
#  <matplotlib.lines.Line2D at 0x1171c4e90>,
#  <matplotlib.lines.Line2D at 0x1171c5b80>,
#  <matplotlib.lines.Line2D at 0x1171c42c0>,
#  <matplotlib.lines.Line2D at 0x1171c5d00>,
#  <matplotlib.lines.Line2D at 0x1171c6090>,
#  <matplotlib.lines.Line2D at 0x117b095b0>,
#  <matplotlib.lines.Line2D at 0x1171c6a50>,
#  <matplotlib.lines.Line2D at 0x1171c5c70>,
#  <matplotlib.lines.Line2D at 0x1171c6f60>,
#  <matplotlib.lines.Line2D at 0x1171c6630>,
#  <matplotlib.lines.Line2D at 0x1171c45f0>,
#  <matplotlib.lines.Line2D at 0x1171c6ae0>,
#  <matplotlib.lines.Line2D at 0x1171c6600>,
#  <matplotlib.lines.Line2D at 0x1219f2150>,
#  <matplotlib.lines.Line2D at 0x1219f0500>,
#  <matplotlib.lines.Line2D at 0x1219f3950>,
#  <matplotlib.lines.Line2D at 0x1219f1bb0>,
#  <matplotlib.lines.Line2D at 0x1219f2ea0>,
#  <matplotlib.lines.Line2D at 0x1219f2ae0>,
#  <matplotlib.lines.Line2D at 0x1219f3e60>,
#  <matplotlib.lines.Line2D at 0x1219f3890>,
#  <matplotlib.lines.Line2D at 0x1219f18b0>,
#  <matplotlib.lines.Line2D at 0x1219f2870>,
#  <matplotlib.lines.Line2D at 0x1219f3770>,
#  <matplotlib.lines.Line2D at 0x1219f1430>,
#  <matplotlib.lines.Line2D at 0x1219f2750>,
#  <matplotlib.lines.Line2D at 0x1219f0fb0>,
#  <matplotlib.lines.Line2D at 0x1219f0fe0>,
#  <matplotlib.lines.Line2D at 0x1219f1910>,
#  <matplotlib.lines.Line2D at 0x1219f3200>,
#  <matplotlib.lines.Line2D at 0x332ae2780>,
#  <matplotlib.lines.Line2D at 0x332ae35f0>,
#  <matplotlib.lines.Line2D at 0x332ae1010>,
#  <matplotlib.lines.Line2D at 0x332ae1130>,
#  <matplotlib.lines.Line2D at 0x332ae0bc0>,
#  <matplotlib.lines.Line2D at 0x332ae0c50>,
#  <matplotlib.lines.Line2D at 0x332ae3830>,
#  <matplotlib.lines.Line2D at 0x332ae0890>,
#  <matplotlib.lines.Line2D at 0x332ae1b20>,
#  <matplotlib.lines.Line2D at 0x332ae3440>,
#  <matplotlib.lines.Line2D at 0x332ae3e00>,
#  <matplotlib.lines.Line2D at 0x332ae3f80>,
#  <matplotlib.lines.Line2D at 0x332ae2870>,
#  <matplotlib.lines.Line2D at 0x332ae2330>,
#  <matplotlib.lines.Line2D at 0x332ae0050>,
#  <matplotlib.lines.Line2D at 0x332ae27e0>,
#  <matplotlib.lines.Line2D at 0x332ae22a0>,
#  <matplotlib.lines.Line2D at 0x332ae0950>,
#  <matplotlib.lines.Line2D at 0x332ae27b0>,
#  <matplotlib.lines.Line2D at 0x332ae1790>,
#  <matplotlib.lines.Line2D at 0x332ae28a0>,
#  <matplotlib.lines.Line2D at 0x332ae3d70>,
#  <matplotlib.lines.Line2D at 0x332ae06e0>,
#  <matplotlib.lines.Line2D at 0x332ae1cd0>,
#  <matplotlib.lines.Line2D at 0x332ae0140>,
#  <matplotlib.lines.Line2D at 0x332ae1730>,
#  <matplotlib.lines.Line2D at 0x332ae3b00>,
#  <matplotlib.lines.Line2D at 0x332ae1eb0>,
#  <matplotlib.lines.Line2D at 0x332ae0a10>,
#  <matplotlib.lines.Line2D at 0x332ae3e30>,
#  <matplotlib.lines.Line2D at 0x332ae3cb0>,
#  <matplotlib.lines.Line2D at 0x332ae13d0>,
#  <matplotlib.lines.Line2D at 0x332ae2f30>,
#  <matplotlib.lines.Line2D at 0x332ae1f10>,
#  <matplotlib.lines.Line2D at 0x332ae1d00>,
#  <matplotlib.lines.Line2D at 0x332ae0ec0>,
#  <matplotlib.lines.Line2D at 0x332ae3110>,
#  <matplotlib.lines.Line2D at 0x332ae0fb0>,
#  <matplotlib.lines.Line2D at 0x332ae31a0>,
#  <matplotlib.lines.Line2D at 0x332ae3bf0>,
#  <matplotlib.lines.Line2D at 0x332ae0230>,
#  <matplotlib.lines.Line2D at 0x332ae2db0>,
#  <matplotlib.lines.Line2D at 0x332ae20f0>,
#  <matplotlib.lines.Line2D at 0x332ae0ef0>,
#  <matplotlib.lines.Line2D at 0x332ae3c50>,
#  <matplotlib.lines.Line2D at 0x332ae1610>,
#  <matplotlib.lines.Line2D at 0x332ae0740>,
#  <matplotlib.lines.Line2D at 0x332ae3470>,
#  <matplotlib.lines.Line2D at 0x332ae3320>,
#  <matplotlib.lines.Line2D at 0x332ae1b50>,
#  <matplotlib.lines.Line2D at 0x332ae0980>,
#  <matplotlib.lines.Line2D at 0x332ae2ed0>,
#  <matplotlib.lines.Line2D at 0x332ae1760>,
#  <matplotlib.lines.Line2D at 0x332ae3ec0>,
#  <matplotlib.lines.Line2D at 0x332ae3590>,
#  <matplotlib.lines.Line2D at 0x1170b10a0>,
#  <matplotlib.lines.Line2D at 0x1170b18b0>,
#  <matplotlib.lines.Line2D at 0x1170b1790>,
#  <matplotlib.lines.Line2D at 0x1170b3470>,
#  <matplotlib.lines.Line2D at 0x1169569c0>,
#  <matplotlib.lines.Line2D at 0x1169567e0>,
#  <matplotlib.lines.Line2D at 0x116956a80>,
#  <matplotlib.lines.Line2D at 0x116907200>,
#  <matplotlib.lines.Line2D at 0x332a5e000>,
#  <matplotlib.lines.Line2D at 0x332a5f290>,
#  <matplotlib.lines.Line2D at 0x332a5efc0>,
#  <matplotlib.lines.Line2D at 0x332a5f230>,
#  <matplotlib.lines.Line2D at 0x332a5faa0>,
#  <matplotlib.lines.Line2D at 0x332a5f890>,
#  <matplotlib.lines.Line2D at 0x332a5e0c0>,
#  <matplotlib.lines.Line2D at 0x332a5f800>,
#  <matplotlib.lines.Line2D at 0x332a5ec90>,
#  <matplotlib.lines.Line2D at 0x332a5ed50>,
#  <matplotlib.lines.Line2D at 0x332a5f4a0>,
#  <matplotlib.lines.Line2D at 0x332a5fcb0>,
#  <matplotlib.lines.Line2D at 0x332a5f830>,
#  <matplotlib.lines.Line2D at 0x332a5f770>,
#  <matplotlib.lines.Line2D at 0x332a5e780>,
#  <matplotlib.lines.Line2D at 0x332a5f980>,
#  <matplotlib.lines.Line2D at 0x332a5e4e0>,
#  <matplotlib.lines.Line2D at 0x332a5e1e0>,
#  <matplotlib.lines.Line2D at 0x115e1c590>,
#  <matplotlib.lines.Line2D at 0x115e1fb30>,
#  <matplotlib.lines.Line2D at 0x329899790>,
#  <matplotlib.lines.Line2D at 0x329899490>,
#  <matplotlib.lines.Line2D at 0x329899730>,
#  <matplotlib.lines.Line2D at 0x329899640>,
#  <matplotlib.lines.Line2D at 0x117ad1ca0>,
#  <matplotlib.lines.Line2D at 0x329899a00>,
#  <matplotlib.lines.Line2D at 0x329899580>,
#  <matplotlib.lines.Line2D at 0x329899c10>,
#  <matplotlib.lines.Line2D at 0x331192f30>,
#  <matplotlib.lines.Line2D at 0x331191610>,
#  <matplotlib.lines.Line2D at 0x3311907a0>,
#  <matplotlib.lines.Line2D at 0x3311922d0>,
#  <matplotlib.lines.Line2D at 0x331191850>,
#  <matplotlib.lines.Line2D at 0x331191a60>,
#  <matplotlib.lines.Line2D at 0x331192ae0>,
#  <matplotlib.lines.Line2D at 0x331193fe0>,
#  <matplotlib.lines.Line2D at 0x331193f80>,
#  <matplotlib.lines.Line2D at 0x331193260>,
#  <matplotlib.lines.Line2D at 0x332aacaa0>,
#  <matplotlib.lines.Line2D at 0x332aaf680>,
#  <matplotlib.lines.Line2D at 0x332aad4f0>,
#  <matplotlib.lines.Line2D at 0x332aaf440>,
#  <matplotlib.lines.Line2D at 0x332aad8b0>,
#  <matplotlib.lines.Line2D at 0x332aad490>,
#  <matplotlib.lines.Line2D at 0x332aad640>,
#  <matplotlib.lines.Line2D at 0x332aadb50>,
#  <matplotlib.lines.Line2D at 0x332aac830>,
#  <matplotlib.lines.Line2D at 0x332aadc40>,
#  <matplotlib.lines.Line2D at 0x332aadb20>,
#  <matplotlib.lines.Line2D at 0x332aae5a0>,
#  <matplotlib.lines.Line2D at 0x332aac5c0>,
#  <matplotlib.lines.Line2D at 0x332aada30>,
#  <matplotlib.lines.Line2D at 0x332aaf110>,
#  <matplotlib.lines.Line2D at 0x332aacd40>,
#  <matplotlib.lines.Line2D at 0x332aadd60>,
#  <matplotlib.lines.Line2D at 0x120c07f20>,
#  <matplotlib.lines.Line2D at 0x332aaef30>,
#  <matplotlib.lines.Line2D at 0x332aaf920>,
#  <matplotlib.lines.Line2D at 0x332aaf7d0>,
#  <matplotlib.lines.Line2D at 0x332aad880>,
#  <matplotlib.lines.Line2D at 0x332aacfe0>,
#  <matplotlib.lines.Line2D at 0x332aaf2f0>,
#  <matplotlib.lines.Line2D at 0x332aaff80>,
#  <matplotlib.lines.Line2D at 0x332aac7a0>,
#  <matplotlib.lines.Line2D at 0x332aaf710>,
#  <matplotlib.lines.Line2D at 0x332aaff50>,
#  <matplotlib.lines.Line2D at 0x332aafda0>,
#  <matplotlib.lines.Line2D at 0x332aacda0>,
#  <matplotlib.lines.Line2D at 0x332aad070>,
#  <matplotlib.lines.Line2D at 0x332aaddf0>,
#  <matplotlib.lines.Line2D at 0x332aad160>,
#  <matplotlib.lines.Line2D at 0x332aad040>,
#  <matplotlib.lines.Line2D at 0x332aad940>,
#  <matplotlib.lines.Line2D at 0x332aaf350>,
#  <matplotlib.lines.Line2D at 0x332aac050>,
#  <matplotlib.lines.Line2D at 0x332aafcb0>,
#  <matplotlib.lines.Line2D at 0x332aaeff0>,
#  <matplotlib.lines.Line2D at 0x332aac410>,
#  <matplotlib.lines.Line2D at 0x332aae600>,
#  <matplotlib.lines.Line2D at 0x332aae9f0>,
#  <matplotlib.lines.Line2D at 0x332aada60>,
#  <matplotlib.lines.Line2D at 0x332aaed80>,
#  <matplotlib.lines.Line2D at 0x332aae750>,
#  <matplotlib.lines.Line2D at 0x332aad340>,
#  <matplotlib.lines.Line2D at 0x332aaf890>,
#  <matplotlib.lines.Line2D at 0x332aae720>,
#  <matplotlib.lines.Line2D at 0x332aac860>,
#  <matplotlib.lines.Line2D at 0x332aaf260>,
#  <matplotlib.lines.Line2D at 0x332aae450>,
#  <matplotlib.lines.Line2D at 0x332aac290>,
#  <matplotlib.lines.Line2D at 0x332aaea50>,
#  <matplotlib.lines.Line2D at 0x332aae6f0>,
#  <matplotlib.lines.Line2D at 0x332aad610>,
#  <matplotlib.lines.Line2D at 0x332aae240>,
#  <matplotlib.lines.Line2D at 0x332aafa70>,
#  <matplotlib.lines.Line2D at 0x332ac4110>,
#  <matplotlib.lines.Line2D at 0x332ac4dd0>,
#  <matplotlib.lines.Line2D at 0x332ac55e0>,
#  <matplotlib.lines.Line2D at 0x332ac4080>,
#  <matplotlib.lines.Line2D at 0x332ac5820>,
#  <matplotlib.lines.Line2D at 0x332ac61b0>,
#  <matplotlib.lines.Line2D at 0x332ac77a0>,
#  <matplotlib.lines.Line2D at 0x332ac7e30>,
#  <matplotlib.lines.Line2D at 0x332ac7b30>,
#  <matplotlib.lines.Line2D at 0x332ac43b0>,
#  <matplotlib.lines.Line2D at 0x332ac7770>,
#  <matplotlib.lines.Line2D at 0x332ac5e50>,
#  <matplotlib.lines.Line2D at 0x332ac44a0>,
#  <matplotlib.lines.Line2D at 0x332ac4a40>,
#  <matplotlib.lines.Line2D at 0x332ac7380>,
#  <matplotlib.lines.Line2D at 0x332ac5700>,
#  <matplotlib.lines.Line2D at 0x332ac7a70>,
#  <matplotlib.lines.Line2D at 0x332ac6f30>,
#  <matplotlib.lines.Line2D at 0x332ac74d0>,
#  <matplotlib.lines.Line2D at 0x332ac49b0>,
#  <matplotlib.lines.Line2D at 0x332ac7110>,
#  <matplotlib.lines.Line2D at 0x332ac4140>,
#  <matplotlib.lines.Line2D at 0x332ac6c30>,
#  <matplotlib.lines.Line2D at 0x332ac53a0>,
#  <matplotlib.lines.Line2D at 0x332ac5550>,
#  <matplotlib.lines.Line2D at 0x332ac5910>,
#  <matplotlib.lines.Line2D at 0x332ac6c00>,
#  <matplotlib.lines.Line2D at 0x332ac75c0>,
#  <matplotlib.lines.Line2D at 0x332ac5a30>,
#  <matplotlib.lines.Line2D at 0x332ac6390>,
#  <matplotlib.lines.Line2D at 0x332ac7da0>,
#  <matplotlib.lines.Line2D at 0x332ac6d80>,
#  <matplotlib.lines.Line2D at 0x332ac6330>,
#  <matplotlib.lines.Line2D at 0x332ac4ef0>,
#  <matplotlib.lines.Line2D at 0x332ac7260>,
#  <matplotlib.lines.Line2D at 0x332ac6900>,
#  <matplotlib.lines.Line2D at 0x332ac6090>,
#  <matplotlib.lines.Line2D at 0x332ac4c50>,
#  <matplotlib.lines.Line2D at 0x332ac7050>,
#  <matplotlib.lines.Line2D at 0x332ac6600>,
#  <matplotlib.lines.Line2D at 0x332ac5cd0>,
#  <matplotlib.lines.Line2D at 0x332ac4770>,
#  <matplotlib.lines.Line2D at 0x332ac6a50>,
#  <matplotlib.lines.Line2D at 0x332ac62d0>,
#  <matplotlib.lines.Line2D at 0x332ac54f0>,
#  <matplotlib.lines.Line2D at 0x332ac72f0>,
#  <matplotlib.lines.Line2D at 0x332ac4710>,
#  <matplotlib.lines.Line2D at 0x332ac6480>,
#  <matplotlib.lines.Line2D at 0x332ac52e0>,
#  <matplotlib.lines.Line2D at 0x332ac5bb0>,
#  <matplotlib.lines.Line2D at 0x332ac4740>,
#  <matplotlib.lines.Line2D at 0x332ac6450>,
#  <matplotlib.lines.Line2D at 0x332ac5e20>,
#  <matplotlib.lines.Line2D at 0x332ac51f0>,
#  <matplotlib.lines.Line2D at 0x332ac5160>,
#  <matplotlib.lines.Line2D at 0x332ac4aa0>,
#  <matplotlib.lines.Line2D at 0x122147290>,
#  <matplotlib.lines.Line2D at 0x1221476b0>,
#  <matplotlib.lines.Line2D at 0x1221455e0>,
#  <matplotlib.lines.Line2D at 0x122146120>,
#  <matplotlib.lines.Line2D at 0x122146660>,
#  <matplotlib.lines.Line2D at 0x122145c40>,
#  <matplotlib.lines.Line2D at 0x122146870>,
#  <matplotlib.lines.Line2D at 0x122146990>,
#  <matplotlib.lines.Line2D at 0x122144f80>,
#  <matplotlib.lines.Line2D at 0x122146270>,
#  <matplotlib.lines.Line2D at 0x122145d30>,
#  <matplotlib.lines.Line2D at 0x122145190>,
#  <matplotlib.lines.Line2D at 0x122146b40>,
#  <matplotlib.lines.Line2D at 0x122144c50>,
#  <matplotlib.lines.Line2D at 0x122147dd0>,
#  <matplotlib.lines.Line2D at 0x122145a90>,
#  <matplotlib.lines.Line2D at 0x1221457c0>,
#  <matplotlib.lines.Line2D at 0x1221461b0>,
#  <matplotlib.lines.Line2D at 0x1221447d0>,
#  <matplotlib.lines.Line2D at 0x1221464e0>,
#  <matplotlib.lines.Line2D at 0x122146f00>,
#  <matplotlib.lines.Line2D at 0x122144440>,
#  <matplotlib.lines.Line2D at 0x1221451c0>,
#  <matplotlib.lines.Line2D at 0x122144d70>,
#  <matplotlib.lines.Line2D at 0x1221479e0>,
#  <matplotlib.lines.Line2D at 0x1221458b0>,
#  <matplotlib.lines.Line2D at 0x122144bc0>,
#  <matplotlib.lines.Line2D at 0x122146510>,
#  <matplotlib.lines.Line2D at 0x122147e00>,
#  <matplotlib.lines.Line2D at 0x122144e60>,
#  <matplotlib.lines.Line2D at 0x122145220>,
#  <matplotlib.lines.Line2D at 0x122145160>,
#  <matplotlib.lines.Line2D at 0x122147920>,
#  <matplotlib.lines.Line2D at 0x122146a50>,
#  <matplotlib.lines.Line2D at 0x1221465d0>,
#  <matplotlib.lines.Line2D at 0x122146600>,
#  <matplotlib.lines.Line2D at 0x122144770>,
#  <matplotlib.lines.Line2D at 0x117b65520>,
#  <matplotlib.lines.Line2D at 0x117b648c0>,
#  <matplotlib.lines.Line2D at 0x117b67830>,
#  <matplotlib.lines.Line2D at 0x117b67d10>,
#  <matplotlib.lines.Line2D at 0x117b67650>,
#  <matplotlib.lines.Line2D at 0x117b643b0>,
#  <matplotlib.lines.Line2D at 0x117b66180>,
#  <matplotlib.lines.Line2D at 0x117b67410>,
#  <matplotlib.lines.Line2D at 0x117b67da0>,
#  <matplotlib.lines.Line2D at 0x117b65a60>,
#  <matplotlib.lines.Line2D at 0x117b64260>,
#  <matplotlib.lines.Line2D at 0x117b67c50>,
#  <matplotlib.lines.Line2D at 0x117b65af0>,
#  <matplotlib.lines.Line2D at 0x117b664e0>,
#  <matplotlib.lines.Line2D at 0x117b64bf0>,
#  <matplotlib.lines.Line2D at 0x117b64a40>,
#  <matplotlib.lines.Line2D at 0x117b679e0>,
#  <matplotlib.lines.Line2D at 0x117b642f0>,
#  <matplotlib.lines.Line2D at 0x117b657c0>,
#  <matplotlib.lines.Line2D at 0x117b664b0>,
#  <matplotlib.lines.Line2D at 0x117b67a40>,
#  <matplotlib.lines.Line2D at 0x332ad80e0>,
#  <matplotlib.lines.Line2D at 0x332ad8200>,
#  <matplotlib.lines.Line2D at 0x332ad8320>,
#  <matplotlib.lines.Line2D at 0x332ad8440>,
#  <matplotlib.lines.Line2D at 0x332ad8560>,
#  <matplotlib.lines.Line2D at 0x332ad8680>,
#  <matplotlib.lines.Line2D at 0x332ad87a0>,
#  <matplotlib.lines.Line2D at 0x332ad88c0>,
#  <matplotlib.lines.Line2D at 0x332ad89e0>,
#  <matplotlib.lines.Line2D at 0x332ad8b00>,
#  <matplotlib.lines.Line2D at 0x332ad8c20>,
#  <matplotlib.lines.Line2D at 0x332ad8d40>,
#  <matplotlib.lines.Line2D at 0x332ad8e60>,
#  <matplotlib.lines.Line2D at 0x332ad8f80>,
#  <matplotlib.lines.Line2D at 0x332ad90a0>,
#  <matplotlib.lines.Line2D at 0x332ad91c0>,
#  <matplotlib.lines.Line2D at 0x332ad92e0>,
#  <matplotlib.lines.Line2D at 0x332ad9400>,
#  <matplotlib.lines.Line2D at 0x332ad9520>,
#  <matplotlib.lines.Line2D at 0x332ad9640>,
#  <matplotlib.lines.Line2D at 0x332ad9760>,
#  <matplotlib.lines.Line2D at 0x332ad9880>,
#  <matplotlib.lines.Line2D at 0x332ad99a0>,
#  <matplotlib.lines.Line2D at 0x332ad9ac0>,
#  <matplotlib.lines.Line2D at 0x332ad9be0>,
#  <matplotlib.lines.Line2D at 0x332ad9d00>,
#  <matplotlib.lines.Line2D at 0x332ad9e20>,
#  <matplotlib.lines.Line2D at 0x332ad9f40>,
#  <matplotlib.lines.Line2D at 0x332ada060>,
#  <matplotlib.lines.Line2D at 0x332ada180>,
#  <matplotlib.lines.Line2D at 0x332ada2a0>,
#  <matplotlib.lines.Line2D at 0x332ada3c0>,
#  <matplotlib.lines.Line2D at 0x332ada4e0>,
#  <matplotlib.lines.Line2D at 0x332ada600>,
#  <matplotlib.lines.Line2D at 0x332ada720>,
#  <matplotlib.lines.Line2D at 0x332ada840>,
#  <matplotlib.lines.Line2D at 0x332ada960>,
#  <matplotlib.lines.Line2D at 0x332adaa80>,
#  <matplotlib.lines.Line2D at 0x332adaba0>,
#  <matplotlib.lines.Line2D at 0x332adacc0>,
#  <matplotlib.lines.Line2D at 0x332adade0>,
#  <matplotlib.lines.Line2D at 0x332adaf00>,
#  <matplotlib.lines.Line2D at 0x332adb020>,
#  <matplotlib.lines.Line2D at 0x332adb140>,
#  <matplotlib.lines.Line2D at 0x332adb260>,
#  <matplotlib.lines.Line2D at 0x332adb380>,
#  <matplotlib.lines.Line2D at 0x332adb4a0>,
#  <matplotlib.lines.Line2D at 0x332adb5c0>,
#  <matplotlib.lines.Line2D at 0x332adb6e0>,
#  <matplotlib.lines.Line2D at 0x332adb800>,
#  <matplotlib.lines.Line2D at 0x332adb920>,
#  <matplotlib.lines.Line2D at 0x332adba40>,
#  <matplotlib.lines.Line2D at 0x332adbb60>,
#  <matplotlib.lines.Line2D at 0x332adbc80>,
#  <matplotlib.lines.Line2D at 0x332adbda0>,
#  <matplotlib.lines.Line2D at 0x332adbec0>,
#  <matplotlib.lines.Line2D at 0x332adbfe0>,
#  <matplotlib.lines.Line2D at 0x332afc140>,
#  <matplotlib.lines.Line2D at 0x332afc260>,
#  <matplotlib.lines.Line2D at 0x332afc380>,
#  <matplotlib.lines.Line2D at 0x332afc4a0>,
#  <matplotlib.lines.Line2D at 0x332afc5c0>,
#  <matplotlib.lines.Line2D at 0x332afc6e0>,
#  <matplotlib.lines.Line2D at 0x332afc800>,
#  <matplotlib.lines.Line2D at 0x332afc920>,
#  <matplotlib.lines.Line2D at 0x332afca40>,
#  <matplotlib.lines.Line2D at 0x332afcb60>,
#  <matplotlib.lines.Line2D at 0x332afcc80>,
#  <matplotlib.lines.Line2D at 0x332afcda0>,
#  <matplotlib.lines.Line2D at 0x332afcec0>,
#  <matplotlib.lines.Line2D at 0x332afcfe0>,
#  <matplotlib.lines.Line2D at 0x332afd100>,
#  <matplotlib.lines.Line2D at 0x332afd220>,
#  <matplotlib.lines.Line2D at 0x332afd340>,
#  <matplotlib.lines.Line2D at 0x332afd460>,
#  <matplotlib.lines.Line2D at 0x332afd580>,
#  <matplotlib.lines.Line2D at 0x332afd6a0>,
#  <matplotlib.lines.Line2D at 0x332afd7c0>,
#  <matplotlib.lines.Line2D at 0x332afd8e0>,
#  <matplotlib.lines.Line2D at 0x332afda00>,
#  <matplotlib.lines.Line2D at 0x332afdb20>,
#  <matplotlib.lines.Line2D at 0x332afdc40>,
#  <matplotlib.lines.Line2D at 0x332afdd60>,
#  <matplotlib.lines.Line2D at 0x332afde80>,
#  <matplotlib.lines.Line2D at 0x332afdfa0>,
#  <matplotlib.lines.Line2D at 0x332afe0c0>,
#  <matplotlib.lines.Line2D at 0x332afe1e0>,
#  <matplotlib.lines.Line2D at 0x332afe300>,
#  <matplotlib.lines.Line2D at 0x332afe420>,
#  <matplotlib.lines.Line2D at 0x332afe540>,
#  <matplotlib.lines.Line2D at 0x332afe660>,
#  <matplotlib.lines.Line2D at 0x332afe780>,
#  <matplotlib.lines.Line2D at 0x332afe8a0>,
#  <matplotlib.lines.Line2D at 0x332afe9c0>,
#  <matplotlib.lines.Line2D at 0x332afeae0>,
#  <matplotlib.lines.Line2D at 0x332afec00>,
#  <matplotlib.lines.Line2D at 0x332afed20>,
#  <matplotlib.lines.Line2D at 0x332afee40>,
#  <matplotlib.lines.Line2D at 0x332afef60>,
#  <matplotlib.lines.Line2D at 0x332aff080>,
#  <matplotlib.lines.Line2D at 0x332aff1a0>,
#  <matplotlib.lines.Line2D at 0x332aff2c0>,
#  <matplotlib.lines.Line2D at 0x332aff3e0>,
#  <matplotlib.lines.Line2D at 0x332aff500>,
#  <matplotlib.lines.Line2D at 0x332aff620>,
#  <matplotlib.lines.Line2D at 0x332aff740>,
#  <matplotlib.lines.Line2D at 0x332aff860>,
#  <matplotlib.lines.Line2D at 0x332aff980>,
#  <matplotlib.lines.Line2D at 0x332affaa0>,
#  <matplotlib.lines.Line2D at 0x332affbc0>,
#  <matplotlib.lines.Line2D at 0x332affce0>,
#  <matplotlib.lines.Line2D at 0x332affe00>,
#  <matplotlib.lines.Line2D at 0x332afff20>,
#  <matplotlib.lines.Line2D at 0x332ac0080>,
#  <matplotlib.lines.Line2D at 0x332ac01a0>,
#  <matplotlib.lines.Line2D at 0x332ac02c0>,
#  <matplotlib.lines.Line2D at 0x332ac03e0>,
#  <matplotlib.lines.Line2D at 0x332ac0500>,
#  <matplotlib.lines.Line2D at 0x332ac0620>,
#  <matplotlib.lines.Line2D at 0x332ac0740>,
#  <matplotlib.lines.Line2D at 0x332ac0860>,
#  <matplotlib.lines.Line2D at 0x332ac0980>,
#  <matplotlib.lines.Line2D at 0x332ac0aa0>,
#  <matplotlib.lines.Line2D at 0x332ac0bc0>,
#  <matplotlib.lines.Line2D at 0x332ac0ce0>,
#  <matplotlib.lines.Line2D at 0x332ac0e00>,
#  <matplotlib.lines.Line2D at 0x332ac0f20>,
#  <matplotlib.lines.Line2D at 0x332ac1040>,
#  <matplotlib.lines.Line2D at 0x332ac1160>,
#  <matplotlib.lines.Line2D at 0x332ac1280>,
#  <matplotlib.lines.Line2D at 0x332ac13a0>,
#  <matplotlib.lines.Line2D at 0x332ac14c0>,
#  <matplotlib.lines.Line2D at 0x332ac15e0>,
#  <matplotlib.lines.Line2D at 0x332ac1700>,
#  <matplotlib.lines.Line2D at 0x332ac1820>,
#  <matplotlib.lines.Line2D at 0x332ac1940>,
#  <matplotlib.lines.Line2D at 0x332ac1a60>,
#  <matplotlib.lines.Line2D at 0x332ac1b80>,
#  <matplotlib.lines.Line2D at 0x332ac1ca0>,
#  <matplotlib.lines.Line2D at 0x332ac1dc0>,
#  <matplotlib.lines.Line2D at 0x332ac1ee0>,
#  <matplotlib.lines.Line2D at 0x332ac2000>,
#  <matplotlib.lines.Line2D at 0x332ac2120>,
#  <matplotlib.lines.Line2D at 0x332ac2240>,
#  <matplotlib.lines.Line2D at 0x332ac2360>,
#  <matplotlib.lines.Line2D at 0x332ac2480>,
#  <matplotlib.lines.Line2D at 0x332ac25a0>,
#  <matplotlib.lines.Line2D at 0x332ac26c0>,
#  <matplotlib.lines.Line2D at 0x332ac27e0>,
#  <matplotlib.lines.Line2D at 0x332ac2900>,
#  <matplotlib.lines.Line2D at 0x332ac2a20>,
#  <matplotlib.lines.Line2D at 0x332ac2b40>,
#  <matplotlib.lines.Line2D at 0x332ac2c60>,
#  <matplotlib.lines.Line2D at 0x332ac2d80>,
#  <matplotlib.lines.Line2D at 0x332ac2ea0>,
#  <matplotlib.lines.Line2D at 0x332ac2fc0>,
#  <matplotlib.lines.Line2D at 0x332ac30e0>,
#  <matplotlib.lines.Line2D at 0x332ac3200>,
#  <matplotlib.lines.Line2D at 0x332ac3320>,
#  <matplotlib.lines.Line2D at 0x332ac3440>,
#  <matplotlib.lines.Line2D at 0x332ac3560>,
#  <matplotlib.lines.Line2D at 0x332ac3680>,
#  <matplotlib.lines.Line2D at 0x332ac37a0>,
#  <matplotlib.lines.Line2D at 0x332ac38c0>,
#  <matplotlib.lines.Line2D at 0x332ac39e0>,
#  <matplotlib.lines.Line2D at 0x332ac3b00>,
#  <matplotlib.lines.Line2D at 0x332ac3c20>,
#  <matplotlib.lines.Line2D at 0x332ac3d40>,
#  <matplotlib.lines.Line2D at 0x332ac3e60>,
#  <matplotlib.lines.Line2D at 0x332ac3f80>,
#  <matplotlib.lines.Line2D at 0x332af40e0>,
#  <matplotlib.lines.Line2D at 0x332af4200>,
#  <matplotlib.lines.Line2D at 0x332af4320>,
#  <matplotlib.lines.Line2D at 0x332af4440>,
#  <matplotlib.lines.Line2D at 0x332af4560>,
#  <matplotlib.lines.Line2D at 0x332af4680>,
#  <matplotlib.lines.Line2D at 0x332af47a0>,
#  <matplotlib.lines.Line2D at 0x332af48c0>,
#  <matplotlib.lines.Line2D at 0x332af49e0>,
#  <matplotlib.lines.Line2D at 0x332af4b00>,
#  <matplotlib.lines.Line2D at 0x332af4c20>,
#  <matplotlib.lines.Line2D at 0x332af4d40>,
#  <matplotlib.lines.Line2D at 0x332af4e60>,
#  <matplotlib.lines.Line2D at 0x332af4f80>,
#  <matplotlib.lines.Line2D at 0x332af50a0>,
#  <matplotlib.lines.Line2D at 0x332af51c0>,
#  <matplotlib.lines.Line2D at 0x332af52e0>,
#  <matplotlib.lines.Line2D at 0x332af5400>,
#  <matplotlib.lines.Line2D at 0x332af5520>,
#  <matplotlib.lines.Line2D at 0x332af5640>,
#  <matplotlib.lines.Line2D at 0x332af5760>,
#  <matplotlib.lines.Line2D at 0x332af5880>,
#  <matplotlib.lines.Line2D at 0x332af59a0>,
#  <matplotlib.lines.Line2D at 0x332af5ac0>,
#  <matplotlib.lines.Line2D at 0x332af5be0>,
#  <matplotlib.lines.Line2D at 0x332af5d00>,
#  <matplotlib.lines.Line2D at 0x332af5e20>,
#  <matplotlib.lines.Line2D at 0x332af5f40>,
#  <matplotlib.lines.Line2D at 0x332af6060>,
#  <matplotlib.lines.Line2D at 0x332af6180>,
#  <matplotlib.lines.Line2D at 0x332af62a0>,
#  <matplotlib.lines.Line2D at 0x332af63c0>,
#  <matplotlib.lines.Line2D at 0x332af64e0>,
#  <matplotlib.lines.Line2D at 0x332af6600>,
#  <matplotlib.lines.Line2D at 0x332af6720>,
#  <matplotlib.lines.Line2D at 0x332af6840>,
#  <matplotlib.lines.Line2D at 0x332af6960>,
#  <matplotlib.lines.Line2D at 0x332af6a80>,
#  <matplotlib.lines.Line2D at 0x332af6ba0>,
#  <matplotlib.lines.Line2D at 0x332af6cc0>,
#  <matplotlib.lines.Line2D at 0x332af6de0>,
#  <matplotlib.lines.Line2D at 0x332af6f00>,
#  <matplotlib.lines.Line2D at 0x332af7020>,
#  <matplotlib.lines.Line2D at 0x332af7140>,
#  <matplotlib.lines.Line2D at 0x332af7260>,
#  <matplotlib.lines.Line2D at 0x332af7380>,
#  <matplotlib.lines.Line2D at 0x332af74a0>,
#  <matplotlib.lines.Line2D at 0x332af75c0>,
#  <matplotlib.lines.Line2D at 0x332af76e0>,
#  <matplotlib.lines.Line2D at 0x332af7800>,
#  <matplotlib.lines.Line2D at 0x332af7920>,
#  <matplotlib.lines.Line2D at 0x332af7a40>,
#  <matplotlib.lines.Line2D at 0x332af7b60>,
#  <matplotlib.lines.Line2D at 0x332af7c80>,
#  <matplotlib.lines.Line2D at 0x332af7da0>,
#  <matplotlib.lines.Line2D at 0x332af7ec0>,
#  <matplotlib.lines.Line2D at 0x332af7fe0>,
#  <matplotlib.lines.Line2D at 0x332b50f80>,
#  <matplotlib.lines.Line2D at 0x332b52d50>,
#  <matplotlib.lines.Line2D at 0x332b53440>,
#  <matplotlib.lines.Line2D at 0x332b53410>,
#  <matplotlib.lines.Line2D at 0x332b51e20>,
#  <matplotlib.lines.Line2D at 0x332b50fb0>,
#  <matplotlib.lines.Line2D at 0x332b52d80>,
#  <matplotlib.lines.Line2D at 0x332b51790>,
#  <matplotlib.lines.Line2D at 0x332b53fb0>,
#  <matplotlib.lines.Line2D at 0x332b52a50>,
#  <matplotlib.lines.Line2D at 0x332b51490>,
#  <matplotlib.lines.Line2D at 0x332b53ec0>,
#  <matplotlib.lines.Line2D at 0x332b529f0>,
#  <matplotlib.lines.Line2D at 0x332b51430>,
#  <matplotlib.lines.Line2D at 0x332b53fe0>,
#  <matplotlib.lines.Line2D at 0x332b52a20>,
#  <matplotlib.lines.Line2D at 0x332b51460>,
#  <matplotlib.lines.Line2D at 0x332b53b90>,
#  <matplotlib.lines.Line2D at 0x332b52570>,
#  <matplotlib.lines.Line2D at 0x332b50fe0>,
#  <matplotlib.lines.Line2D at 0x332b538f0>,
#  <matplotlib.lines.Line2D at 0x332b52330>,
#  <matplotlib.lines.Line2D at 0x332b50d40>,
#  <matplotlib.lines.Line2D at 0x332b53920>,
#  <matplotlib.lines.Line2D at 0x332b52360>,
#  <matplotlib.lines.Line2D at 0x332b50d70>,
#  <matplotlib.lines.Line2D at 0x332b53950>,
#  <matplotlib.lines.Line2D at 0x332b52390>,
#  <matplotlib.lines.Line2D at 0x332b50da0>,
#  <matplotlib.lines.Line2D at 0x332b53980>,
#  <matplotlib.lines.Line2D at 0x332b523c0>,
#  <matplotlib.lines.Line2D at 0x332b50dd0>,
#  <matplotlib.lines.Line2D at 0x332b539b0>,
#  <matplotlib.lines.Line2D at 0x332b523f0>,
#  <matplotlib.lines.Line2D at 0x332b50e00>,
#  <matplotlib.lines.Line2D at 0x332b539e0>,
#  <matplotlib.lines.Line2D at 0x332b52420>,
#  <matplotlib.lines.Line2D at 0x332b50e30>,
#  <matplotlib.lines.Line2D at 0x332b53a10>,
#  <matplotlib.lines.Line2D at 0x332b52450>,
#  <matplotlib.lines.Line2D at 0x332b50e60>,
#  <matplotlib.lines.Line2D at 0x332b53a40>,
#  <matplotlib.lines.Line2D at 0x332b52480>,
#  <matplotlib.lines.Line2D at 0x332b50e90>,
#  <matplotlib.lines.Line2D at 0x332b53a70>,
#  <matplotlib.lines.Line2D at 0x332b524b0>,
#  <matplotlib.lines.Line2D at 0x332b50ec0>,
#  <matplotlib.lines.Line2D at 0x332b53aa0>,
#  <matplotlib.lines.Line2D at 0x332b524e0>,
#  <matplotlib.lines.Line2D at 0x332b50ef0>,
#  <matplotlib.lines.Line2D at 0x332b53ad0>,
#  <matplotlib.lines.Line2D at 0x332b52510>,
#  <matplotlib.lines.Line2D at 0x332b50f20>,
#  <matplotlib.lines.Line2D at 0x332b53b00>,
#  <matplotlib.lines.Line2D at 0x332b52540>,
#  <matplotlib.lines.Line2D at 0x332b50f50>,
#  <matplotlib.lines.Line2D at 0x332b30080>,
#  <matplotlib.lines.Line2D at 0x332b301a0>,
#  <matplotlib.lines.Line2D at 0x332b302c0>,
#  <matplotlib.lines.Line2D at 0x332b303e0>,
#  <matplotlib.lines.Line2D at 0x332b30500>,
#  <matplotlib.lines.Line2D at 0x332b30620>,
#  <matplotlib.lines.Line2D at 0x332b30740>,
#  <matplotlib.lines.Line2D at 0x332b30860>,
#  <matplotlib.lines.Line2D at 0x332b30980>,
#  <matplotlib.lines.Line2D at 0x332b30aa0>,
#  <matplotlib.lines.Line2D at 0x332b30bc0>,
#  <matplotlib.lines.Line2D at 0x332b30ce0>,
#  <matplotlib.lines.Line2D at 0x332b30e00>,
#  <matplotlib.lines.Line2D at 0x332b30f20>,
#  <matplotlib.lines.Line2D at 0x332b31040>,
#  <matplotlib.lines.Line2D at 0x332b31160>,
#  <matplotlib.lines.Line2D at 0x332b31280>,
#  <matplotlib.lines.Line2D at 0x332b313a0>,
#  <matplotlib.lines.Line2D at 0x332b314c0>,
#  <matplotlib.lines.Line2D at 0x332b315e0>,
#  <matplotlib.lines.Line2D at 0x332b31700>,
#  <matplotlib.lines.Line2D at 0x332b31820>,
#  <matplotlib.lines.Line2D at 0x332b31940>,
#  <matplotlib.lines.Line2D at 0x332b31a60>,
#  <matplotlib.lines.Line2D at 0x332b31b80>,
#  <matplotlib.lines.Line2D at 0x332b31ca0>,
#  <matplotlib.lines.Line2D at 0x332b31dc0>,
#  <matplotlib.lines.Line2D at 0x332b31ee0>,
#  <matplotlib.lines.Line2D at 0x332b32000>,
#  <matplotlib.lines.Line2D at 0x332b32120>,
#  <matplotlib.lines.Line2D at 0x332b32240>,
#  <matplotlib.lines.Line2D at 0x332b32360>,
#  <matplotlib.lines.Line2D at 0x332b32480>,
#  <matplotlib.lines.Line2D at 0x332b325a0>,
#  <matplotlib.lines.Line2D at 0x332b326c0>,
#  <matplotlib.lines.Line2D at 0x332b327e0>,
#  <matplotlib.lines.Line2D at 0x332b32900>,
#  <matplotlib.lines.Line2D at 0x332b32a20>,
#  <matplotlib.lines.Line2D at 0x332b32b40>,
#  <matplotlib.lines.Line2D at 0x332b32c60>,
#  <matplotlib.lines.Line2D at 0x332b32d80>,
#  <matplotlib.lines.Line2D at 0x332b32ea0>,
#  <matplotlib.lines.Line2D at 0x332b32fc0>,
#  <matplotlib.lines.Line2D at 0x332b330e0>,
#  <matplotlib.lines.Line2D at 0x332b33200>,
#  <matplotlib.lines.Line2D at 0x332b33320>,
#  <matplotlib.lines.Line2D at 0x332b33440>,
#  <matplotlib.lines.Line2D at 0x332b33560>,
#  <matplotlib.lines.Line2D at 0x332b33680>,
#  <matplotlib.lines.Line2D at 0x332b337a0>,
#  <matplotlib.lines.Line2D at 0x332b338c0>,
#  <matplotlib.lines.Line2D at 0x332b339e0>,
#  <matplotlib.lines.Line2D at 0x332b33b00>,
#  <matplotlib.lines.Line2D at 0x332b33c20>,
#  <matplotlib.lines.Line2D at 0x332b33d40>,
#  <matplotlib.lines.Line2D at 0x332b33e60>,
#  <matplotlib.lines.Line2D at 0x332b33f80>,
#  <matplotlib.lines.Line2D at 0x332b880e0>,
#  <matplotlib.lines.Line2D at 0x332b88200>,
#  <matplotlib.lines.Line2D at 0x332b88320>,
#  <matplotlib.lines.Line2D at 0x332b88440>,
#  <matplotlib.lines.Line2D at 0x332b88560>,
#  <matplotlib.lines.Line2D at 0x332b88680>,
#  <matplotlib.lines.Line2D at 0x332b887a0>,
#  <matplotlib.lines.Line2D at 0x332b888c0>,
#  <matplotlib.lines.Line2D at 0x332b889e0>,
#  <matplotlib.lines.Line2D at 0x332b88b00>,
#  <matplotlib.lines.Line2D at 0x332b88c20>,
#  <matplotlib.lines.Line2D at 0x332b88d40>,
#  <matplotlib.lines.Line2D at 0x332b88e60>,
#  <matplotlib.lines.Line2D at 0x332b88f80>,
#  <matplotlib.lines.Line2D at 0x332b890a0>,
#  <matplotlib.lines.Line2D at 0x332b891c0>,
#  <matplotlib.lines.Line2D at 0x332b892e0>,
#  <matplotlib.lines.Line2D at 0x332b89400>,
#  <matplotlib.lines.Line2D at 0x332b89520>,
#  <matplotlib.lines.Line2D at 0x332b89640>,
#  <matplotlib.lines.Line2D at 0x332b89760>,
#  <matplotlib.lines.Line2D at 0x332b89880>,
#  <matplotlib.lines.Line2D at 0x332b899a0>,
#  <matplotlib.lines.Line2D at 0x332b89ac0>,
#  <matplotlib.lines.Line2D at 0x332b89be0>,
#  <matplotlib.lines.Line2D at 0x332b89d00>,
#  <matplotlib.lines.Line2D at 0x332b89e20>,
#  <matplotlib.lines.Line2D at 0x332b89f40>,
#  <matplotlib.lines.Line2D at 0x332b8a060>,
#  <matplotlib.lines.Line2D at 0x332b8a180>,
#  <matplotlib.lines.Line2D at 0x332b8a2a0>,
#  <matplotlib.lines.Line2D at 0x332b8a3c0>,
#  <matplotlib.lines.Line2D at 0x332b8a4e0>,
#  <matplotlib.lines.Line2D at 0x332b8a600>,
#  <matplotlib.lines.Line2D at 0x332b8a720>,
#  <matplotlib.lines.Line2D at 0x332b8a840>,
#  <matplotlib.lines.Line2D at 0x332b8a960>,
#  <matplotlib.lines.Line2D at 0x332b8aa80>,
#  <matplotlib.lines.Line2D at 0x332b8aba0>,
#  <matplotlib.lines.Line2D at 0x332b8acc0>,
#  <matplotlib.lines.Line2D at 0x332b8ade0>,
#  <matplotlib.lines.Line2D at 0x332b8af00>,
#  <matplotlib.lines.Line2D at 0x332b8b020>,
#  <matplotlib.lines.Line2D at 0x332b8b140>,
#  <matplotlib.lines.Line2D at 0x332b8b260>,
#  <matplotlib.lines.Line2D at 0x332b8b380>,
#  <matplotlib.lines.Line2D at 0x332b8b4a0>,
#  <matplotlib.lines.Line2D at 0x332b8b5c0>,
#  <matplotlib.lines.Line2D at 0x332b8b6e0>,
#  <matplotlib.lines.Line2D at 0x332b8b800>,
#  <matplotlib.lines.Line2D at 0x332b8b920>,
#  <matplotlib.lines.Line2D at 0x332b8ba40>,
#  <matplotlib.lines.Line2D at 0x332b8bb60>,
#  <matplotlib.lines.Line2D at 0x332b8bc80>,
#  <matplotlib.lines.Line2D at 0x332b8bda0>,
#  <matplotlib.lines.Line2D at 0x332b8bec0>,
#  <matplotlib.lines.Line2D at 0x332b8bfe0>,
#  <matplotlib.lines.Line2D at 0x332b24140>,
#  <matplotlib.lines.Line2D at 0x332b24260>,
#  <matplotlib.lines.Line2D at 0x332b24380>,
#  <matplotlib.lines.Line2D at 0x332b244a0>,
#  <matplotlib.lines.Line2D at 0x332b245c0>,
#  <matplotlib.lines.Line2D at 0x332b246e0>,
#  <matplotlib.lines.Line2D at 0x332b24800>,
#  <matplotlib.lines.Line2D at 0x332b24920>,
#  <matplotlib.lines.Line2D at 0x332b24a40>,
#  <matplotlib.lines.Line2D at 0x332b24b60>,
#  <matplotlib.lines.Line2D at 0x332b24c80>,
#  <matplotlib.lines.Line2D at 0x332b24da0>,
#  <matplotlib.lines.Line2D at 0x332b24ec0>,
#  <matplotlib.lines.Line2D at 0x332b24fe0>,
#  <matplotlib.lines.Line2D at 0x332b25100>,
#  <matplotlib.lines.Line2D at 0x332b25220>,
#  <matplotlib.lines.Line2D at 0x332b25340>,
#  <matplotlib.lines.Line2D at 0x332b25460>,
#  <matplotlib.lines.Line2D at 0x332b25580>,
#  <matplotlib.lines.Line2D at 0x332b256a0>,
#  <matplotlib.lines.Line2D at 0x332b257c0>,
#  <matplotlib.lines.Line2D at 0x332b258e0>,
#  <matplotlib.lines.Line2D at 0x332b25a00>,
#  <matplotlib.lines.Line2D at 0x332b25b20>,
#  <matplotlib.lines.Line2D at 0x332b25c40>,
#  <matplotlib.lines.Line2D at 0x332b25d60>,
#  <matplotlib.lines.Line2D at 0x332b25e80>,
#  <matplotlib.lines.Line2D at 0x332b25fa0>,
#  <matplotlib.lines.Line2D at 0x332b260c0>,
#  <matplotlib.lines.Line2D at 0x332b261e0>,
#  <matplotlib.lines.Line2D at 0x332b26300>,
#  <matplotlib.lines.Line2D at 0x332b26420>,
#  <matplotlib.lines.Line2D at 0x332b26540>,
#  <matplotlib.lines.Line2D at 0x332b26660>,
#  <matplotlib.lines.Line2D at 0x332b26780>,
#  <matplotlib.lines.Line2D at 0x332b268a0>,
#  <matplotlib.lines.Line2D at 0x332b269c0>,
#  <matplotlib.lines.Line2D at 0x332b26ae0>,
#  <matplotlib.lines.Line2D at 0x332b26c00>,
#  <matplotlib.lines.Line2D at 0x332b26d20>,
#  <matplotlib.lines.Line2D at 0x332b26e40>,
#  <matplotlib.lines.Line2D at 0x332b26f60>,
#  <matplotlib.lines.Line2D at 0x332b27080>,
#  <matplotlib.lines.Line2D at 0x332b271a0>,
#  <matplotlib.lines.Line2D at 0x332b272c0>,
#  <matplotlib.lines.Line2D at 0x332b273e0>,
#  <matplotlib.lines.Line2D at 0x332b27500>,
#  <matplotlib.lines.Line2D at 0x332b27620>,
#  <matplotlib.lines.Line2D at 0x332b27740>,
#  <matplotlib.lines.Line2D at 0x332b27860>,
#  <matplotlib.lines.Line2D at 0x332b27980>,
#  <matplotlib.lines.Line2D at 0x332b27aa0>,
#  <matplotlib.lines.Line2D at 0x332b27bc0>,
#  <matplotlib.lines.Line2D at 0x332b27ce0>,
#  <matplotlib.lines.Line2D at 0x332b27e00>,
#  <matplotlib.lines.Line2D at 0x332b27f20>,
#  <matplotlib.lines.Line2D at 0x332bd0080>,
#  <matplotlib.lines.Line2D at 0x332bd01a0>,
#  <matplotlib.lines.Line2D at 0x332bd02c0>,
#  <matplotlib.lines.Line2D at 0x332bd03e0>,
#  <matplotlib.lines.Line2D at 0x332bd0500>,
#  <matplotlib.lines.Line2D at 0x332bd0620>,
#  <matplotlib.lines.Line2D at 0x332bd0740>,
#  <matplotlib.lines.Line2D at 0x332bd0860>,
#  <matplotlib.lines.Line2D at 0x332bd0980>,
#  <matplotlib.lines.Line2D at 0x332bd0aa0>,
#  <matplotlib.lines.Line2D at 0x332bd0bc0>,
#  <matplotlib.lines.Line2D at 0x332bd0ce0>,
#  <matplotlib.lines.Line2D at 0x332bd0e00>,
#  <matplotlib.lines.Line2D at 0x332bd0f20>,
#  <matplotlib.lines.Line2D at 0x332bd1040>,
#  <matplotlib.lines.Line2D at 0x332bd1160>,
#  <matplotlib.lines.Line2D at 0x332bd1280>,
#  <matplotlib.lines.Line2D at 0x332bd13a0>,
#  <matplotlib.lines.Line2D at 0x332bd14c0>,
#  <matplotlib.lines.Line2D at 0x332bd15e0>,
#  <matplotlib.lines.Line2D at 0x332bd1700>,
#  <matplotlib.lines.Line2D at 0x332bd1820>,
#  <matplotlib.lines.Line2D at 0x332bd1940>,
#  <matplotlib.lines.Line2D at 0x332bd1a60>,
#  <matplotlib.lines.Line2D at 0x332bd1b80>,
#  <matplotlib.lines.Line2D at 0x332bd1ca0>,
#  <matplotlib.lines.Line2D at 0x332bd1dc0>,
#  <matplotlib.lines.Line2D at 0x332bd1ee0>,
#  ...]
